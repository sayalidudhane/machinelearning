# %% [markdown]
# <a href="https://colab.research.google.com/github/sayalidudhane/machinelearning/blob/main/LinearDiscriminant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
df = pd.read_csv("/Seed_Data.csv")
df
# Out:
#          A      P       C     LK     WK  A_Coef    LKG  target
# 0    15.26  14.84  0.8710  5.763  3.312   2.221  5.220       0
# 1    14.88  14.57  0.8811  5.554  3.333   1.018  4.956       0
# 2    14.29  14.09  0.9050  5.291  3.337   2.699  4.825       0
# 3    13.84  13.94  0.8955  5.324  3.379   2.259  4.805       0
# 4    16.14  14.99  0.9034  5.658  3.562   1.355  5.175       0
# ..     ...    ...     ...    ...    ...     ...    ...     ...
# 205  12.19  13.20  0.8783  5.137  2.981   3.631  4.870       2
# 206  11.23  12.88  0.8511  5.140  2.795   4.325  5.003       2
# 207  13.20  13.66  0.8883  5.236  3.232   8.315  5.056       2
# 208  11.84  13.21  0.8521  5.175  2.836   3.598  5.044       2
# 209  12.30  13.34  0.8684  5.243  2.974   5.637  5.063       2
#
# [210 rows x 8 columns]

# %%
y = df['target']         
X = df.iloc[:, [0, 1, 2, 3, 4,5,6]].values

# %%
lda = LinearDiscriminantAnalysis(n_components=2)
lda_X = lda.fit(X, y).transform(X)

# %%
plt.scatter(lda_X[y == 0, 0], lda_X[y == 0, 1], s =100, c = 'red', label = 'Target 0')
plt.scatter(lda_X[y == 1, 0], lda_X[y == 1, 1], s =100,  c = 'yellow', label = 'Target 1')
plt.scatter(lda_X[y == 2, 0], lda_X[y == 2, 1], s =100,  c = 'blue', label = 'Target 2')
plt.title('LDA plot for Seed Dataset')
plt.legend()

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis()
lda.fit(X, y)
yp= lda.predict(X)
lda.decision_function(X)
# Out:
# array([[  4.13971978, -10.51823856, -10.45029699],
#        [  6.14783496, -12.03843645, -10.93821428],
#        [  3.65467258, -12.49005086,  -7.99343749],
#        [  4.98446307, -14.95382577,  -6.85945307],
#        [  3.22186134,  -7.36279085, -12.68788626],
#        [  2.79417951, -11.61545915,  -8.00753614],
#        [ -0.03492462,  -9.16776341,  -7.62612774],
#        [  2.59138299, -12.84323502,  -6.57696375],
#        [ -3.61898689,  -1.86317759, -11.34665129],
#        [ -0.14205522,  -4.93029001, -11.75647054],
#        [ -0.42342628,  -7.76413952,  -8.64124997],
#        [  3.31304331, -12.61509162,  -7.52676746],
#        [  7.44649354, -17.92194121,  -6.3533681 ],
#        [  5.8244339 , -16.43453205,  -6.21871762],
#        [  6.91847699, -17.2995006 ,  -6.44779217],
#        [  4.02876663, -12.59235384,  -8.26522856],
#        [ -0.22881101, -11.5197834 ,  -5.08022136],
#        [  3.26576209,  -8.43996644, -11.65461143],
# ...
